# %%
# %matplotlib inline

# %%
import pandas as pd
import seaborn as sns

# %%
beers = pd.read_csv("https://raw.githubusercontent.com/nickhould/craft-beers-dataset/master/data/processed/beers.csv")

breweries = pd.read_csv("https://raw.githubusercontent.com/nickhould/craft-beers-dataset/master/data/processed/breweries.csv")

# %%
sns.set(color_codes=True)
sns.set_palette(sns.color_palette("muted"))

sns.distplot(beers["ibu"].dropna());
# Out:
# /Users/tien/miniconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.heatmap(beers[["abv", "ibu", "ounces"]].corr(),annot=True, linewidths=0.2)

# %%
beers[["name", "style"]].describe()
# Out:
#                    name         style
# count              2410          2405
# unique             2305            99
# top     Nonstop Hef Hop  American IPA
# freq                 12           424

# %%
breweries
# Out:
#      Unnamed: 0                                 name           city state   id
# 0             0                   NorthGate Brewing     Minneapolis    MN    0
# 1             1            Against the Grain Brewery     Louisville    KY    1
# 2             2             Jack's Abby Craft Lagers     Framingham    MA    2
# 3             3            Mike Hess Brewing Company      San Diego    CA    3
# 4             4              Fort Point Beer Company  San Francisco    CA    4
# 5             5                COAST Brewing Company     Charleston    SC    5
# 6             6         Great Divide Brewing Company         Denver    CO    6
# 7             7                     Tapistry Brewing       Bridgman    MI    7
# 8             8                     Big Lake Brewing        Holland    MI    8
# 9             9           The Mitten Brewing Company   Grand Rapids    MI    9
# 10           10                       Brewery Vivant   Grand Rapids    MI   10
# 11           11                     Petoskey Brewing       Petoskey    MI   11
# 12           12                   Blackrocks Brewery      Marquette    MI   12
# 13           13               Perrin Brewing Company  Comstock Park    MI   13
# 14           14          Witch's Hat Brewing Company     South Lyon    MI   14
# 15           15             Founders Brewing Company   Grand Rapids    MI   15
# 16           16                    Flat 12 Bierwerks   Indianapolis    IN   16
# 17           17              Tin Man Brewing Company     Evansville    IN   17
# 18           18               Black Acre Brewing Co.   Indianapolis    IN   18
# 19           19                    Brew Link Brewing     Plainfield    IN   19
# 20           20                   Bare Hands Brewery        Granger    IN   20
# 21           21                  Three Pints Brewing   Martinsville    IN   21
# 22           22                Four Fathers Brewing      Valparaiso    IN   22
# 23           23                 Indiana City Brewing   Indianapolis    IN   23
# 24           24                     Burn 'Em Brewing  Michigan City    IN   24
# 25           25             Sun King Brewing Company   Indianapolis    IN   25
# 26           26                   Evil Czech Brewery      Mishawaka    IN   26
# 27           27            450 North Brewing Company       Columbus    IN   27
# 28           28               Taxman Brewing Company   Bargersville    IN   28
# 29           29                  Cedar Creek Brewery   Seven Points    TX   29
# ..          ...                                  ...            ...   ...  ...
# 528         528            Asheville Brewing Company      Asheville    NC  528
# 529         529                   Northwoods Brewpub     Eau Claire    WI  529
# 530         530             Buckbean Brewing Company           Reno    NV  530
# 531         531                Dolores River Brewery        Dolores    CO  531
# 532         532            Flat Rock Brewing Company       Smithton    PA  532
# 533         533                Abita Brewing Company  Abita Springs    LA  533
# 534         534              Mammoth Brewing Company  Mammoth Lakes    CA  534
# 535         535         Harvest Moon Brewing Company           Belt    MT  535
# 536         536         Grand Canyon Brewing Company       Williams    AZ  536
# 537         537      Lewis and Clark Brewing Company         Helena    MT  537
# 538         538               Dundee Brewing Company      Rochester    NY  538
# 539         539           Twin Lakes Brewing Company     Greenville    DE  539
# 540         540         Mother Earth Brewing Company        Kinston    NC  540
# 541         541              Arcadia Brewing Company   Battle Creek    MI  541
# 542         542         Angry Minnow Brewing Company        Hayward    WI  542
# 543         543       Great Northern Brewing Company      Whitefish    MT  543
# 544         544                    Pyramid Breweries        Seattle    WA  544
# 545         545            Lancaster Brewing Company      Lancaster    PA  545
# 546         546              Upstate Brewing Company         Elmira    NY  546
# 547         547  Moat Mountain Smoke House & Brew...   North Conway    NH  547
# 548         548             Prescott Brewing Company       Prescott    AZ  548
# 549         549             Mogollon Brewing Company      Flagstaff    AZ  549
# 550         550           Wind River Brewing Company       Pinedale    WY  550
# 551         551                    Silverton Brewery      Silverton    CO  551
# 552         552                Mickey Finn's Brewery   Libertyville    IL  552
# 553         553                  Covington Brewhouse      Covington    LA  553
# 554         554                      Dave's Brewfarm         Wilson    WI  554
# 555         555                Ukiah Brewing Company          Ukiah    CA  555
# 556         556              Butternuts Beer and Ale  Garrattsville    NY  556
# 557         557        Sleeping Lady Brewing Company      Anchorage    AK  557
#
# [558 rows x 5 columns]

# %%
from speedml import Speedml
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-edc2a4586093> in <module>()
# ----> 1 from speedml import Speedml
#
# ModuleNotFoundError: No module named 'speedml'
